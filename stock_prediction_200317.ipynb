# %% [markdown]
# ## 姓名: 蔡紹軍
# ## 受試日期: 2020年3月10日

# %%
import os
import csv
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 1000)
plt.style.use('ggplot') 
import warnings
warnings.filterwarnings('ignore')

import talib as ta
from talib import abstract
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM, TimeDistributed, RepeatVector, Input
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import GroupKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error, mean_absolute_error
import lightgbm as lgb
import xgboost as xgb

# %% [markdown]
# # Read Data

# %%
for _, _, filename in os.walk("/input/ctbcsec-interview"):
    print(filename)
# Out:
# ['CorpInfo_2014.csv', 'ETFInfo_2019.csv', 'Off_Corp_2014.csv', 'Test_X.csv', 'Test_Y.csv', 'Train_X.csv', 'Train_Y.csv']

# %%
def read_csv():
    BASE_PATH = "/input/ctbcsec-interview/"
    print("Reading Train_X.csv as dataframe...")
    train_X = pd.read_csv(BASE_PATH + "Train_X.csv", encoding='cp950')
    print("Completed! train_X have {} columns, {} rows".format(train_X.shape[0], train_X.shape[1]))

    print("Reading Train_Y.csv as dataframe...")
    train_y = pd.read_csv(BASE_PATH + "Train_Y.csv", encoding='cp950')
    print("Completed! train_y have {} columns, {} rows".format(train_y.shape[0], train_y.shape[1]))

    print("Reading Test_X.csv as dataframe...")
    test_X = pd.read_csv(BASE_PATH + "Test_X.csv", encoding='cp950')
    print("Completed! test_X have {} columns, {} rows".format(test_X.shape[0], test_X.shape[1]))

    print("Reading Test_Y.csv as dataframe...")
    test_y = pd.read_csv(BASE_PATH + "Test_Y.csv", encoding='cp950')
    print("Completed! test_y have {} columns, {} rows".format(test_y.shape[0], test_y.shape[1]))

    print("Reading CorpInfo_2014.csv as dataframe...")
    corp_info = pd.read_csv(BASE_PATH + "CorpInfo_2014.csv", engine='python')
    print("Completed! corp_info have {} columns, {} rows".format(corp_info.shape[0], corp_info.shape[1]))

    print("Reading ETFInfo_2019.csv as dataframe...")
    etf_info = pd.read_csv(BASE_PATH + "ETFInfo_2019.csv", engine='python')
    print("Completed! etf_info have {} columns, {} rows".format(etf_info.shape[0], etf_info.shape[1]))

    print("Reading Off_Corp_2014.csv as dataframe...")
    off_corp = pd.read_csv(BASE_PATH + "Off_Corp_2014.csv", engine='python')
    print("Completed! off_corp have {} columns, {} rows".format(off_corp.shape[0], off_corp.shape[1]))
    
    return train_X, train_y, test_X, test_y, corp_info, etf_info, off_corp

# %%
#modify specific columns label for Ta-Lib
def label_rename(*dfs):
    def toid(df):
        df.rename(columns={'股票代號': 'id'}, inplace=True)
        if '開盤價' in df.columns:
            df.rename(columns={'開盤價': 'open', '收盤價': 'close', '最高價': 'high', '最低價': 'low', '成交量': 'volume', '成交量變動...': 'volume_change'}, inplace=True)
    for d in dfs:
        toid(d)
    
    print('Renamed the label of columns.')

# %%
def to_dateframe(*dfs):
    for df in dfs:
        df.rename(columns={'日期': 'date'}, inplace=True)
        df['dateframe'] = pd.to_datetime(df['date'], format='%Y%m%d')
        df['month'] = df['dateframe'].dt.month
        df['dayofweek'] = df['dateframe'].dt.dayofweek
        df['weekofyear'] = df['dateframe'].dt.weekofyear
        df['quarter'] = df['dateframe'].dt.quarter
    print('Completed date transform!')

# %%
train_X, train_y, test_X, test_y, corp_info, etf_info, off_corp = read_csv() #讀取CSV
all_data_X = pd.concat([train_X, test_X]) #合併Train & Test以利後續處理

label_rename(all_data_X, train_X, off_corp, corp_info, etf_info) #修改columns label
to_dateframe(all_data_X, train_X, train_y, test_X, test_y) #將日期轉為dateframe格式

all_data_X.sort_values('date', inplace=True)
all_data_X.reset_index(drop=True, inplace=True)
# Out:
# Reading Train_X.csv as dataframe...
# Completed! train_X have 405210 columns, 28 rows
# Reading Train_Y.csv as dataframe...
# Completed! train_y have 237 columns, 2 rows
# Reading Test_X.csv as dataframe...
# Completed! test_X have 17798 columns, 28 rows
# Reading Test_Y.csv as dataframe...
# Completed! test_y have 10 columns, 2 rows
# Reading CorpInfo_2014.csv as dataframe...
# Completed! corp_info have 1568 columns, 53 rows
# Reading ETFInfo_2019.csv as dataframe...
# Completed! etf_info have 152 columns, 65 rows
# Reading Off_Corp_2014.csv as dataframe...
# Completed! off_corp have 11 columns, 34 rows
# Renamed the label of columns.
# Completed date transform!

# %%
corp_info.id = corp_info.id.astype('str')
off_corp.id = off_corp.id.astype('str')
corp_info.rename(columns={'指數彙編分類代號': 'cate_id'}, inplace=True)
etf_info.rename(columns={'ETF類型代號': 'cate_id'}, inplace=True)
etf_info['cate_id'] = etf_info['cate_id'].apply(lambda x: 'ETF_' + x)
all_data_X = all_data_X.merge(corp_info[['id', '產業名稱', 'cate_id']], on=['id'], how='left')
all_data_X.update(etf_info[['id', 'cate_id']], join='left')

# %%
stock_id_list = list(corp_info.id) + list(off_corp.id) + ['2002A', '2833A'] #特別股
etf_id_list = list(etf_info.id)

# %%
trade_volume = train_X.groupby('date').agg(np.sum)['volume']

fig, ax = plt.subplots(2, 1, figsize=(15, 6), dpi=240)
ax[0].set_title('Trade Value and TAIEX Price per Day')
plt.xlabel('Date')

ax[0].set_ylabel('TAIEX Close')
ax[0].plot(train_y.dateframe, train_y.Target_Y)

ax[1].set_ylabel('Trade Volume')
ax[1].bar(train_y.dateframe, trade_volume)

plt.show()

# %%
train_y['Target_Y'].describe()
# Out:
# count     237.000000
# mean     9009.377384
# std       293.439287
# min      8264.480000
# 25%      8808.610000
# 50%      8999.520000
# 75%      9223.180000
# max      9569.170000
# Name: Target_Y, dtype: float64

# %%
all_data_X.head()
# Out:
#        date    id 股票名稱   open   high    low  close    漲跌  漲幅...  振幅...  \
# 0  20140102  0050   全新  30.50  30.90  30.15  30.60  0.20   0.66   2.47
# 1  20140102  0051  台新金  14.65  14.70  14.60  14.70  0.05   0.34   0.68
# 2  20140102  0052  新光金  10.30  10.45  10.25  10.40  0.10   0.97   1.94
# 3  20140102  0053  國票金  10.00  10.05   9.97   9.99  0.00   0.00   0.80
# 4  20140102  0054  永豐金  14.85  14.85  14.70  14.80 -0.05  -0.34   1.01
#
#     volume    成交筆數   成交金額.千.   均張  volume_change  均張變動...   股本.百萬.  總市值.億.  \
# 0   1964.0   908.0   59928.0  2.2          32.52    -4.35   2465.0    75.4
# 1  16217.0  2721.0  237738.0  6.0          95.43    13.21  82368.0  1210.8
# 2  44245.0  6176.0  459781.0  7.2         194.71    35.85  93288.0   970.2
# 3   1371.0   363.0   13719.0  3.8          16.98   322.22  26281.0   262.5
# 4   5743.0  1149.0   84965.0  5.0         -57.38   -23.08  82177.0  1216.2
#
#    市值比重...   本益比  股價淨值比  本益比.近四季.  週轉率...  成交值比重...  漲跌停     均價      成交量.股.  \
# 0    0.031  14.5   2.18      16.2    0.79     0.065  0.0  30.51   1964103.0
# 1    0.450  10.0   1.15       8.7    0.20     0.258  0.0  14.66  16217580.0
# 2    0.395  10.7   0.99       9.2    0.47     0.499  0.0  10.39  44245189.0
# 3    0.107  14.3   0.94      27.2    0.05     0.015  0.0  10.01   1371060.0
# 4    0.495  11.3   1.20      11.7    0.07     0.092  0.0  14.79   5743463.0
#
#       RTIME  dateframe  month  dayofweek  weekofyear  quarter     產業名稱 cate_id
# 0  123459.0 2014-01-02      1          3           1        1  電子–通信網路   ETF_A
# 1  123459.0 2014-01-02      1          3           1        1     金融保險   ETF_A
# 2  123459.0 2014-01-02      1          3           1        1     金融保險   ETF_A
# 3  123459.0 2014-01-02      1          3           1        1     金融保險   ETF_A
# 4  123459.0 2014-01-02      1          3           1        1     金融保險   ETF_A

# %%
stock_df = all_data_X[all_data_X.id.isin(stock_id_list)]
stock_df.isnull().sum()
# Out:
# date                 0
# id                   0
# 股票名稱                 0
# open                 0
# high                 0
# low                  0
# close                0
# 漲跌                   0
# 漲幅...                0
# 振幅...                0
# volume               0
# 成交筆數                 0
# 成交金額.千.              0
# 均張                3805
# volume_change     7367
# 均張變動...           7395
# 股本.百萬.             493
# 總市值.億.             740
# 市值比重...          12773
# 本益比              66541
# 股價淨值比             1563
# 本益比.近四季.         93608
# 週轉率...             740
# 成交值比重...          6631
# 漲跌停                  0
# 均價                   0
# 成交量.股.               0
# RTIME             2316
# dateframe            0
# month                0
# dayofweek            0
# weekofyear           0
# quarter              0
# 產業名稱              1531
# cate_id           1778
# dtype: int64

# %% [markdown]
# # Build Regressor Model API

# %%
class Base_Model(object):
    def __init__(self, train, test, features, n_fold=5):
        self.train = train
        self.test = test
        self.features = features
        self.target = 'close_T+10'
        self.n_fold = n_fold
        self.params = self.get_params()
        self.y_pred, self.oof_pred, self.models = self.fit()
        
    def get_params(self):
        raise NotImplementError
    
    def fit(self):
        models = []
        y_pred = np.zeros((self.test.shape[0],))
        oof_pred = np.zeros((self.train.shape[0]))
        kf = KFold(n_splits=self.n_fold, random_state=2019, shuffle=True)
        for i, (train_idx, val_idx) in enumerate(kf.split(self.train, self.train[self.target])):
            X_train, y_train = self.train[self.features].iloc[train_idx], self.train[self.target].iloc[train_idx]
            X_val, y_val = self.train[self.features].iloc[val_idx], self.train[self.target].iloc[val_idx]
            model = self.train_model(X_train, y_train, X_val, y_val)
            oof_pred[val_idx] = model.predict(X_val).reshape(oof_pred[val_idx].shape)
            y_pred += model.predict(self.test[self.features]).reshape(y_pred.shape) / self.n_fold
            print('Fold {} score is {}'.format(i+1, np.sqrt(mean_squared_error(y_val, oof_pred[val_idx]))))
            models.append(model)
        score = np.sqrt(mean_squared_error(self.train[self.target], oof_pred))
        print(f'oof scores is {score}')
            
        return y_pred, oof_pred, models

# %%
class LGB_regr(Base_Model):
    def train_model(self, X_train, y_train, X_val, y_val):
        model = lgb.LGBMRegressor(**self.params)
        return model.fit(X=X_train, y=y_train,
                         eval_set=[(X_train, y_train), (X_val, y_val)],
                         #eval_metric=eval_qwk_lgb_regr,
                         verbose=0,
                         early_stopping_rounds=self.params['early_stopping_rounds'])
    def get_params(self):
        params = {'n_estimators': 5000,
                  'boostin_type': 'gdbt',
                  'objective': 'regression',
                  'metric': 'rmse',
                  'subsample': 0.75,
                  'subsample': 1,
                  'learning': 0.015,
                  'feature_fraction': 0.9,
                  'max_depth': 15,
                  'lambda_l1': 1,
                  'lambda_l2': 1,
                  #'verbose': 500,
                  'early_stopping_rounds': 100,
                  'eval_metric': 'cappa',
                  'random_seed': 46
                 }
        return params

# %%
class XGB_regr(Base_Model):
    def train_model(self, X_train, y_train, X_val, y_val):
        model = xgb.XGBRegressor(**self.params)
        return model.fit(X=X_train, y=y_train,
                         eval_set=[(X_train, y_train), (X_val, y_val)],
                         #eval_metric=eval_qwk_xgb_regr,
                         verbose=0,
                         early_stopping_rounds=self.params['early_stopping_rounds'])
    
    def get_params(self):
        params = {'colsample_bytree': 0.4603,
                  'gamma': 0.0468, 
                  'learning_rate': 0.01,
                  'max_depth': 5, 
                  'min_child_weight': 1.7817,
                  'n_estimators': 2200,
                  'reg_alpha': 0.4640,
                  'reg_lambda': 0.8571,
                  'subsample': 0.5213,
                  'objective':'reg:squarederror',
                  'silent': 1,
                  'random_state': 46,
                  'nthread': -1,
                  #'eval_metric': 'eval_qwk_xgb_regr',
                  #'disable_default_eval_metric': 1,
                  'early_stopping_rounds': 100,
                  }
        return params

# %% [markdown]
# # Data Enconder

# %%
def data_encoder(train, target):
    data = []
    vol_keeper = 0
    updown_count = {'up': 0, 'down': 0}
    adxr_raise = np.zeros((target.shape[0] + 10))
    adxr_down = np.zeros((target.shape[0] + 10))
    
    #個股表現 不含ETF
    for i, (sid, bystock) in enumerate(train[train.id.isin(stock_id_list)].groupby('id', sort=False)):
        if bystock.shape[0] == 247 and i > 16:
            
            #adxr: 搭配di預測漲跌個股數量
            adxr = abstract.ADXR(bystock).reset_index(drop=True)
            adx = abstract.ADX(bystock).reset_index(drop=True)
            minus_di = abstract.MINUS_DI(bystock).reset_index(drop=True)
            plus_di = abstract.PLUS_DI(bystock).reset_index(drop=True)
            adxr_raise += (plus_di > minus_di) & (adx > adxr)
            adxr_down += (plus_di < minus_di) & (adx > adxr)
   
            #CCI
            #cci = abstract.CCI(df)
            #willr = abstract.WILLR(df)
    
    #
    for i, (d, df) in enumerate(train.groupby('date', sort=False)):
        
        stock_df = df[df.id.isin(stock_id_list)]
        etf_df = df[df.id.isin(etf_id_list)]
        index_df = df[(df.id.str.contains('TW')) | (df.id.str.startswith('R'))]

        date = df.date.iloc[0]
        datestamp = df.dateframe.iloc[0]
        month = df.month.iloc[0]
        dayofweek = df.dayofweek.iloc[0]
        weekofyear = df.weekofyear.iloc[0]
        quarter = df.quarter.iloc[0]
        
        T10_close = target.Target_Y.iloc[i] if i < target.shape[0] else 0
        close = target.Target_Y[i-10] if i >= 10 else 0 
        raise_rate = (target.Target_Y[i-1]/close) - 1 if i != 0 and i < 237 else 0
        vol = stock_df.volume.sum()
        vol_diff = vol / vol_keeper - 1 if vol_keeper != 0 else 0
        vol_keeper = vol
        
        #cate transform
        cate_vol = stock_df.pivot_table(index='date', columns='cate_id', values='volume', aggfunc=np.sum)
        
        features = updown_count.copy()
        features['date'] = date
        features['datestamp'] = datestamp
        features['month'] = month
        features['dayofweek'] = dayofweek
        features['weekofyear'] = weekofyear
        features['quarter'] = quarter
        features['volume'] = vol
        features['volume_diff'] = vol_diff
        features['close'] = close
        features['close_T+10'] = T10_close
        #features['raise_rate'] = raise_rate
        
        data.append(features)
            
    #大盤指標 by ta-lib functions
    data_df = pd.DataFrame(data).reset_index()
    single = ['SMA','EMA','WMA','TRIMA','KAMA','T3',
              'HT_DCPERIOD', 'HT_TRENDMODE',
              'APO', 'CMO', 'MOM', 'PPO', 'ROC', 'ROCR', 'ROCR100', 'RSI',
              'STDDEV', 'TSF', 'VAR']
    
    for f in single:
        try:
            output = eval('ta.' + f + '(data_df.close)')
            output.name = f.lower() if type(output) == pd.core.series.Series else None
            data_df = pd.merge(data_df, pd.DataFrame(output), left_on = data_df.index, right_on = output.index)
            data_df = data_df.set_index('key_0')
        except:
            print(f)
    
    
    upband, midband, lowerband = ta.BBANDS(data_df.close)
    data_df['BB_mid'] = midband
    data_df['BB_locate'] = data_df['close'] - data_df['BB_mid']
    data_df['BB_width'] = upband - lowerband
    
    data_df['adxr_raise'] = adxr_raise
    data_df['adxr_down'] = adxr_down
    
    data_df.set_index('index', drop=True, inplace=True)
    #data_df = pd.merge(data_df, pd.DataFrame(output), left_on = data_df.index, right_on = output.index)    
    
    return data_df

# %%
#合併前五日特徵
def merge_Tminus_days(df, minus_tday=5):
    shift_df = df.copy()
    for i in range(minus_tday):
        df = df.merge(shift_df.shift(i+1), left_on=df.index, right_on=shift_df.index, suffixes=['_'+str(i), '_'+str(i+1)])
        df = df.drop(columns=['key_0'])
    return df

# %%
ec_all_data = data_encoder(all_data_X, train_y)

# %%
ec_all_data
# Out:
#        up  down      date  datestamp  month  dayofweek  weekofyear  quarter  \
# index
# 0       0     0  20140102 2014-01-02      1          3           1        1
# 233    2051655.0    -0.004466  9027.33     9214.07  9048.853667  9053.542289
# 234    2095102.0     0.021177  8985.63     9218.50  9048.212667  9049.160851
# 235    2302375.0     0.098932  8950.91     9286.28  9046.937000  9042.822087
# 236    2789972.0     0.211780  8828.36     9268.43  9042.462333  9028.985823
# 237    2469105.0    -0.115007  8878.63        0.00  9042.049333  9019.285447
# 238    3088898.0     0.251019  8999.52        0.00  9044.946000  9018.010257
# 239    2335562.0    -0.243885  9095.00        0.00  9046.446667  9022.977337
# 240    2282267.0    -0.022819  9097.71        0.00  9048.565667  9027.798799
# 241    3107081.0     0.361401  9186.18        0.00  9057.473333  9038.016941
# 242    2229838.0    -0.282337  9158.70        0.00  9063.407667  9045.802945
# 243    2111451.0    -0.053092  9214.07        0.00  9071.114000  9056.658884
# 244    1764422.0    -0.164356  9218.50        0.00  9082.251000  9067.100246
# 245    2689881.0     0.524511  9286.28        0.00  9096.491333  9081.240876
# 246    2314559.0    -0.139531  9268.43        0.00  9106.664333  9093.317593
#
#                wma        trima         kama           t3  ht_dcperiod  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# 5              NaN          NaN          NaN          NaN          NaN
# 6              NaN          NaN          NaN          NaN          NaN
# 7              NaN          NaN          NaN          NaN          NaN
# 8              NaN          NaN          NaN          NaN          NaN
# 9              NaN          NaN          NaN          NaN          NaN
# 10             NaN          NaN          NaN          NaN          NaN
# 11             NaN          NaN          NaN          NaN          NaN
# 12             NaN          NaN          NaN          NaN          NaN
# 13             NaN          NaN          NaN          NaN          NaN
# 14             NaN          NaN          NaN          NaN          NaN
# 15             NaN          NaN          NaN          NaN          NaN
# 16             NaN          NaN          NaN          NaN          NaN
# 17             NaN          NaN          NaN          NaN          NaN
# 18             NaN          NaN          NaN          NaN          NaN
# 19             NaN          NaN          NaN          NaN          NaN
# 20             NaN          NaN          NaN          NaN          NaN
# 21             NaN          NaN          NaN          NaN          NaN
# 22             NaN          NaN          NaN          NaN          NaN
# 23             NaN          NaN          NaN          NaN          NaN
# 24             NaN          NaN          NaN  8653.926702          NaN
# 25             NaN          NaN          NaN  8608.445321          NaN
# 26             NaN          NaN          NaN  8580.390512          NaN
# 27             NaN          NaN          NaN  8567.632713          NaN
# 28             NaN          NaN          NaN  8566.548367          NaN
# 29     7494.734215  6561.985250          NaN  8565.155683          NaN
# 30     7683.744839  6912.247250  8552.821868  8570.052191          NaN
# 31     7851.595548  7226.539250  8555.619658  8574.294661          NaN
# 32     8002.004731  7505.476000  8562.807042  8577.883819    15.646696
# 33     8135.600108  7750.553625  8576.489865  8583.448065    17.211765
# 34     8253.197075  7962.564958  8599.195599  8594.457789    18.843663
# 35     8349.788495  8140.841375  8600.183091  8603.683438    20.432273
# 36     8424.820387  8284.847958  8584.292467  8603.834514    21.923232
# 243    2.249668e+03  9150.332     63.738    189.722663       469.0       90.0
# 244    1.956627e+03  9175.032     43.468    176.935118       509.0       83.0
# 245    1.813767e+03  9212.746     73.534    170.353356       577.0       72.0
# 246    2.022155e+03  9229.196     39.234    179.873521       611.0       77.0

# %%
y = ec_all_data['close_T+10']
data_timestamp = ec_all_data['datestamp']
ec_all_data = ec_all_data.drop(columns=['date', 'datestamp', 'close_T+10'])

# %%
ec_merged = merge_Tminus_days(ec_all_data)

# %%
ec_test = ec_merged.tail(10).reset_index()
ec_train = ec_merged.iloc[30: -10].reset_index()

# %%
#features = ec_all_data.loc[(ec_all_data.sum(axis=1) != 0), (ec_all_data.sum(axis=0) != 0)].columns
features = ec_merged.columns

# %%
#標準化
sc = StandardScaler() 
train_scaled = pd.DataFrame(sc.fit_transform(ec_train[features]), columns=features)
test_scaled = pd.DataFrame(sc.transform(ec_test[features]), columns=features)

# %%
train_scaled['close_T+10'] = y[30:-10].reset_index(drop=True)
test_scaled['close_T+10'] = y[-10:].reset_index(drop=True)

# %% [markdown]
# # Train Model

# %%
lgb_regr = LGB_regr(train_scaled, test_scaled, features, n_fold=5)
# Out:
# Fold 1 score is 64.14543490072339
# Fold 2 score is 100.01025021021815
# Fold 3 score is 78.57945262725849
# Fold 4 score is 81.02871610863292
# Fold 5 score is 59.623765518900136
# oof scores is 78.05025304704974

# %%
xgb_regr = XGB_regr(train_scaled, test_scaled, features, n_fold=5)
# Out:
# Fold 1 score is 67.38293277170874
# Fold 2 score is 77.5183061468555
# Fold 3 score is 71.33363309302702
# Fold 4 score is 73.63124689762189
# Fold 5 score is 68.10325880436055
# oof scores is 71.69962695662916

# %%
lgb_oof_pred = lgb_regr.oof_pred
lgb_y_pred = lgb_regr.y_pred
xgb_oof_pred = xgb_regr.oof_pred
xgb_y_pred = xgb_regr.y_pred

# %%
plt.figure(figsize=(15, 4), dpi=200)
plt.plot(data_timestamp[:-10], train_y.Target_Y, 'k', alpha=0.8)
plt.plot(train_y.iloc[30:].dateframe, lgb_oof_pred, 'b', alpha=0.6)
plt.plot(test_y.dateframe, lgb_y_pred, 'b:')
plt.plot(train_y.iloc[30:].dateframe, xgb_oof_pred, 'r', alpha=0.6)
plt.plot(test_y.dateframe, xgb_y_pred, 'r--')

plt.title("TAIEX TREND")
plt.legend(('Actual', 'LGB_Train predict', 'LGB_Test predict', 'XGB_Train predict', 'XGB_Test predict'), loc='best', framealpha=0.5)
plt.xlabel('Date')
plt.ylabel('TAIEX')
plt.show()

# %%
feature_importance = list(zip(features, list(lgb_regr.models[0].feature_importances_)))
dt = pd.DataFrame(feature_importance,  columns=['feature' ,'importance'])
dt.sort_values(by=['importance'], ascending=False).head(10)
# Out:
#            feature  importance
# 7    volume_diff_0         125
# 161    BB_locate_4         123
# 73   volume_diff_2         117
# 29     BB_locate_0         110
# 40   volume_diff_1         105
# 106  volume_diff_3         102
# 180  ht_dcperiod_5          95
# 147  ht_dcperiod_4          87
# 172  volume_diff_5          80
# 105       volume_3          79

# %% [markdown]
# # LSTM

# %%
def train_windows(df, y, ref_day=10, predict_day=10):
    X_train, Y_train = [], []
    for i in range(df.shape[0] - ref_day + 1):
        X_train.append(np.array(df.iloc[i: i + ref_day]))
        Y_train.append(np.array(y.iloc[i: i + ref_day]))
    return np.array(X_train), np.array(Y_train)

# %%
def lstm_stock_model(shape):
    model = Sequential()
    model.add(LSTM(20, input_shape=(shape[1], shape[2]), return_sequences=True)) 
    model.add(Dropout(0.4))
    model.add(LSTM(20, input_shape=(shape[1], shape[2]), return_sequences=True)) 
    model.add(TimeDistributed(Dense(1)))
    
    adam = tf.keras.optimizers.Adam(lr=0.0003)
    model.compile(loss='mae',
                  optimizer=adam,
                  metrics=['mean_absolute_error'])

    model.summary()
    return model

# %%
sc = StandardScaler() 
lstm_train_scaled = pd.DataFrame(sc.fit_transform(ec_all_data), columns=ec_all_data.columns)
y_scaled = pd.DataFrame(sc.fit_transform(pd.DataFrame(y)), columns={'y'})['y']

# %%
all_x, all_y = train_windows(lstm_train_scaled.iloc[32:], y_scaled.iloc[32:])
all_y = all_y[:,:,np.newaxis]

# %%
lstm_train_X, lstm_train_y = all_x[:-10,:,:], all_y[:-10,:,:]
lstm_test_X, lstm_test_y = all_x[-10:,:,:], all_y[-10:,:,:]

# %%
print(lstm_train_X.shape, lstm_train_y.shape)
# Out:
# (196, 10, 33) (196, 10, 1)

# %%
model = lstm_stock_model(lstm_train_X.shape)
callback = EarlyStopping(monitor="val_loss", patience=14, verbose=1, mode="auto")
checkpoints = ModelCheckpoint('10_days_lstm_v2.h5', save_best_only=True)
lr_function = ReduceLROnPlateau(monitor='val_loss', patience=7, verbose=1, factor=0.2, min_lr=0.000003)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 20)            4320
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 20)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 20)            3280
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 1)             21
# =================================================================
# Total params: 7,621
# Trainable params: 7,621
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(lstm_train_X, lstm_train_y,
                    epochs=2000,
                    batch_size=4,
                    validation_split=0.1,
                    callbacks=[callback, checkpoints, lr_function],
                    verbose=1,
                    shuffle=True)
# Out:
# Train on 176 samples, validate on 20 samples
# Epoch 1/2000
# 176/176 [==============================] - 3s 19ms/sample - loss: 0.2026 - mean_absolute_error: 0.2026 - val_loss: 0.1797 - val_mean_absolute_error: 0.1797
# Epoch 2/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.1260 - mean_absolute_error: 0.1260 - val_loss: 0.1312 - val_mean_absolute_error: 0.1312
# Epoch 3/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.1096 - mean_absolute_error: 0.1096 - val_loss: 0.1291 - val_mean_absolute_error: 0.1291
# Epoch 4/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.1018 - mean_absolute_error: 0.1018 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219
# Epoch 5/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0947 - mean_absolute_error: 0.0947 - val_loss: 0.1258 - val_mean_absolute_error: 0.1258
# Epoch 6/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0871 - mean_absolute_error: 0.0871 - val_loss: 0.1127 - val_mean_absolute_error: 0.1127
# Epoch 7/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0834 - mean_absolute_error: 0.0834 - val_loss: 0.1115 - val_mean_absolute_error: 0.1115
# Epoch 8/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0789 - mean_absolute_error: 0.0789 - val_loss: 0.1058 - val_mean_absolute_error: 0.1058
# Epoch 9/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0758 - mean_absolute_error: 0.0758 - val_loss: 0.1098 - val_mean_absolute_error: 0.1098
# Epoch 10/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0712 - mean_absolute_error: 0.0712 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 11/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 12/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0654 - mean_absolute_error: 0.0654 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
# Epoch 13/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0642 - mean_absolute_error: 0.0642 - val_loss: 0.0974 - val_mean_absolute_error: 0.0974
# Epoch 14/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0615 - mean_absolute_error: 0.0615 - val_loss: 0.0892 - val_mean_absolute_error: 0.0892
# Epoch 15/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0619 - mean_absolute_error: 0.0619 - val_loss: 0.0935 - val_mean_absolute_error: 0.0935
# Epoch 16/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.0925 - val_mean_absolute_error: 0.0925
# Epoch 17/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.0864 - val_mean_absolute_error: 0.0864
# Epoch 18/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.0859 - val_mean_absolute_error: 0.0859
# Epoch 19/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0555 - mean_absolute_error: 0.0555 - val_loss: 0.0862 - val_mean_absolute_error: 0.0862
# Epoch 20/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0840 - val_mean_absolute_error: 0.0840
# Epoch 21/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0522 - mean_absolute_error: 0.0522 - val_loss: 0.0859 - val_mean_absolute_error: 0.0859
# Epoch 22/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.0842 - val_mean_absolute_error: 0.0842
# Epoch 23/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0525 - mean_absolute_error: 0.0525 - val_loss: 0.0837 - val_mean_absolute_error: 0.0837
# Epoch 24/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.0845 - val_mean_absolute_error: 0.0845
# Epoch 25/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.0836 - val_mean_absolute_error: 0.0836
# Epoch 26/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0501 - mean_absolute_error: 0.0501 - val_loss: 0.0821 - val_mean_absolute_error: 0.0821
# Epoch 27/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0508 - mean_absolute_error: 0.0508 - val_loss: 0.0825 - val_mean_absolute_error: 0.0825
# Epoch 28/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0487 - mean_absolute_error: 0.0487 - val_loss: 0.0840 - val_mean_absolute_error: 0.0840
# Epoch 29/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0487 - mean_absolute_error: 0.0487 - val_loss: 0.0821 - val_mean_absolute_error: 0.0821
# Epoch 30/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0839 - val_mean_absolute_error: 0.0839
# Epoch 31/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0470 - mean_absolute_error: 0.0470 - val_loss: 0.0840 - val_mean_absolute_error: 0.0840
# Epoch 32/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0463 - mean_absolute_error: 0.0463 - val_loss: 0.0844 - val_mean_absolute_error: 0.0844
# Epoch 33/2000
# 172/176 [============================>.] - ETA: 0s - loss: 0.0443 - mean_absolute_error: 0.0443
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835
# Epoch 34/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832
# Epoch 35/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.0833 - val_mean_absolute_error: 0.0833
# Epoch 36/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0435 - mean_absolute_error: 0.0435 - val_loss: 0.0831 - val_mean_absolute_error: 0.0831
# Epoch 37/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0829 - val_mean_absolute_error: 0.0829
# Epoch 38/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0442 - mean_absolute_error: 0.0442 - val_loss: 0.0827 - val_mean_absolute_error: 0.0827
# Epoch 39/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0433 - mean_absolute_error: 0.0433 - val_loss: 0.0831 - val_mean_absolute_error: 0.0831
# Epoch 40/2000
# 168/176 [===========================>..] - ETA: 0s - loss: 0.0453 - mean_absolute_error: 0.0453
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.0830 - val_mean_absolute_error: 0.0830
# Epoch 41/2000
# 176/176 [==============================] - 0s 2ms/sample - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0830 - val_mean_absolute_error: 0.0830
# Epoch 42/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0828 - val_mean_absolute_error: 0.0828
# Epoch 43/2000
# 176/176 [==============================] - 0s 3ms/sample - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0828 - val_mean_absolute_error: 0.0828
# Epoch 00043: early stopping

# %%
plt.figure(figsize=(20, 14))
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
plt.show()

# %%
lstm_y_pred = sc.inverse_transform(model.predict(lstm_test_X))[:,-1,:].reshape(10,)

# %%
lstm_oof_pred = sc.inverse_transform(model.predict(lstm_train_X))[:,-1,:]

# %%
plt.figure(figsize=(14, 4), dpi=200)
plt.plot(data_timestamp[:-10], train_y.Target_Y, '')
plt.plot(train_y.iloc[41:].dateframe, lstm_oof_pred, 'g--')
plt.plot(test_y.dateframe, lstm_y_pred, 'b--')

plt.title("TAIEX TREND")
plt.legend(('Actual', 'Train predict', 'Test predict'), loc='best', framealpha=0.5)
plt.xlabel('Date')
plt.ylabel('TAIEX')
plt.show()

# %%
def model_evaluate(pred_y, y):
    mae = mean_absolute_error(pred_y, y)
    return mae
lgb_eva = model_evaluate(lgb_oof_pred, train_scaled['close_T+10'])
xgb_eva = model_evaluate(xgb_oof_pred, train_scaled['close_T+10'])
lstm_eva = model_evaluate(lstm_oof_pred, sc.inverse_transform(lstm_train_y)[:,-1,:])
print('Backtesting score LGB: {:.3f}, XGB: {:.3f}, LSTM: {:.3f}'.format(lgb_eva, xgb_eva, lstm_eva))
# Out:
# Backtesting score LGB: 58.946, XGB: 54.854, LSTM: 52.055

# %%
weights = {'lbg': 0.40, 'xgb': 0.40, 'lstm': 0.20}
final_pred = (lgb_y_pred * weights['lbg']) + (xgb_y_pred * weights['xgb'] + lstm_y_pred * weights['lstm'])

# %%
test_y['Target_Y'] = final_pred

# %%
test_y.drop(columns={'dateframe', 'month', 'dayofweek', 'weekofyear', 'quarter'})
# Out:
#        date     Target_Y
# 0  20141218  9071.796951
# 1  20141219  9044.322086
# 2  20141222  9049.359829
# 3  20141223  9066.867532
# 4  20141224  9088.738368
# 5  20141225  9080.626603
# 6  20141226  9104.834908
# 7  20141227  9127.303737
# 8  20141229  9154.962978
# 9  20141230  9165.276091
